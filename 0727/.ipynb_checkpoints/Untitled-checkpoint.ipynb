# %% [markdown]
# # 과제 (시도: 30점, 구현 정도: 30점, 설명: 40점. 부분점수 있음.)
# <p>과제는 이번 시간에 다뤘던 내용을 참조하여 <b>나만의 주식 종목 추천시스템</b>을 만드는 것입니다.
# 예시에서 다뤘던 추천시스템은 다음과 같은 Workflow로 진행되었습니다.</p>
# <p></p>
# <p><b>주제 의식</b>: 새롭게 주식 포트폴리오를 구성하려는 S&P500 투자자에게 포트폴리오 추천시스템을 만들자!</p>
# <p></p>
# <p><b>데이터 수집 방법</b>: yfinance에서 제공하는 Ticker 정보 활용해 S&P500 데이터의 info를 수집.</p>
# <p></p>
# <p><b>데이터 전처리 방법</b>: 먼저 주식을 추천하는 데 의미가 있다고 생각하는 데이터만 수집. 결측치 처리는 EDA 과정을 기반으로 진행. 최대한 원본 데이터를 유지하는 방향으로 진행. yfinance에만 없고 인터넷에서 제공되는 데이터의 경우 직접 검색해서 excel에 입력했음.</p>
# <p><b>사용 모델</b>: k-Nearest Neighbors. Pipeline을 이용해 수치형 데이터와 범주형 데이터를 전처리. 수치형 데이터의 경우 StandardScaler를 활용해 정규화, 범주형 데이터의 경우 One-HotEncoder통해 원핫 인코딩.</p>
# <p><b>구현 방식</b>: kNN의 모델 결과 중 distance 정보를 받아서 주어진 포트폴리오의 금액 가중치를 기반으로 distance의 가중합이 낮은 순으로 출력하게 하여 주어진 포트폴리오와 가장 유사한 종목을 추천하도록 하였음. 이런 추천 방식을 갖고 간단한 input을 기반으로 User-Interactive한 주식 종목 포트폴리오 빌더를 구현함. 포트폴리오 빌더는 간단히 주어진 포트폴리오에 종목을 추가, 제거할 수 있으며, 추천을 더 이상 받고 싶지 않은 종목은 감출 수 있도록 구현했음.</p>
# <h3>여러분만의 주식 종목 추천시스템 구현에 도전해보세요!</h3>
# <p><b>가이드라인</b>: 주제 의식, 데이터 수집, 데이터 전처리, 사용 모델, 구현 방식 중에서 하나를 여러분의 방식대로 바꿔보시는 것을 추천드립니다. 하나가 바뀌면 다른 것도 따라서 바뀔 수도 있습니다. </p>
# <p><b>예시1</b>: 나스닥 투자자에게 포트폴리오 추천시스템을 만드는 것으로 주제 의식을 변경할 수 있습니다. 그렇다면 데이터 수집 방법에서 NASDAQ 데이터의 info를 수집하는 방식으로 변경이 되어야 할 것입니다.</p>
# <p><b>예시2</b>: S&P500 데이터의 info 뿐만 아니라 다른 데이터를 입력할 수 있습니다. yfinance 라이브러리의 다른 함수를 사용할 수도 있으며, 웹 데이터에서 가져와서 ticker 기준으로 주어진 info 데이터와 병합할 수 있습니다. 그렇게 될 경우 포트폴리오 추천시스템의 품질이 향상할 것으로 기대할 수 있습니다. 또한, 이 경우 새롭게 추가된 데이터의 전처리도 여러 방식을 적용할 수 있을 것입니다.</p>
# <p><b>예시3</b>: 데이터 전처리를 조금 더 매끄럽게 하여 추천의 품질을 향상시킬 수 있을 것입니다. 해당 데이터를 전처리하면서 여러분의 전처리 실력을 향상시켜보세요!</p>
# <p><b>예시4</b>: 사용 모델을 kNN에서 다른 모델로 사용하는 것입니다. 예를 들어 RandomForestRegressor를 사용해 recommendationmean (애널리스트 추천 점수)를 예측하는 모델을 구현할 수 있습니다. 이제 새로운 데이터가 들어왔을 때 (회사의 정보가 업데이트 되었을 때) 미리 학습된 모델의 결과로 애널리스트 예상 추천점수를 보여주고, 예상 추천점수가 높은 순서로 추천하는 것입니다. 이 방식을 사용했을 경우, 예상 추천점수가 빈 경우에 대해서 결측치 처리를 한다던지, 예측 정확도를 높이기 위해서 Log Transformation 등 다양한 전처리 방식의 변화가 예상된다고 볼 수 있습니다. 이 부분은 조금 어렵기 때문에 웬만해서는 kNN을 사용하는 방향으로 과제를 진행하시는 것을 추천드립니다.</p>
# <p><b>예시5</b>: 이미 학습된 모델에서 pandas numpy 및 python 지식을 활용해 구현 방식을 조절할 수 있습니다. 예를 들어, 가중치를 1로 모두 초기화하는 것이 아니라, 사용자가 계속해서 입력하게 할 수 있습니다. 따라서 사용자는 포트폴리오 비중까지 고려한 복잡한 포트폴리오를 구성할 수 있게됩니다. 혹은, 분산 투자를 장려하기 위해서 이미 사용자가 선택한 섹터는 제외하고 추천할 수 있습니다. 그 외에도, 본인의 투자 가치에 맞는 방식으로 추천시스템을 고도화할 수 있습니다. 이 부분을 수정하시는 것을 추천드리며, pandas/numpy 등 python 지식을 늘리는 데에 도움이 되고, 추천시스템을 더 잘 이해할 수 있게 될 것입니다.</p>
# <h4>그 외에도 다양한 방식으로 나만의 주식 종목 추천시스템을 구현할 수 있을 것입니다. 파이팅입니다!</h4>

# %% [markdown]
# ## 아래에 코드를 작성해주세요.

# %%
import yfinance as yf
from yahoo_fin.stock_info import get_data
import yahoo_fin.stock_info as si

# %%
# 나스닥 가져오기
si.tickers_nasdaq()
# Out:
# ['AACG',
#  'AACI',
#  'AACIU',
#  'AACIW',
#  'AADI',
#  'AADR',
#  'AAL',
#  'AAME',
#  'AAOI',
#  'AAON',
#  'AAPB',
#  'AAPD',
#  'AAPL',
#  'AAPU',
#  'AAXJ',
#  'ABCB',
#  'ABCL',
#  'ABCM',
#  'ABEO',
#  'ABIO',
#  'ABL',
#  'ABLLW',
#  'ABNB',
#  'ABOS',
#  'ABSI',
#  'ABUS',
#  'ABVC',
#  'ACAB',
#  'ACABU',
#  'ACABW',
#  'ACAC',
#  'ACACU',
#  'ACACW',
#  'ACAD',
#  'ACAH',
#  'ACAHU',
#  'ACAHW',
#  'ACAX',
#  'ACAXR',
#  'ACAXU',
#  'ACAXW',
#  'ACB',
#  'ACBA',
#  'ACBAU',
#  'ACBAW',
#  'ACCD',
#  'ACDC',
#  'ACDCW',
#  'ACER',
#  'ACET',
#  'ACGL',
#  'ACGLN',
#  'ACGLO',
#  'ACGN',
#  'ACHC',
#  'ACHL',
#  'ACHV',
#  'ACIU',
#  'ACIW',
#  'ACLS',
#  'ACLX',
#  'ACMR',
#  'ACNB',
#  'ACNT',
#  'ACON',
#  'ACONW',
#  'ACOR',
#  'ACRS',
#  'ACRV',
#  'ACRX',
#  'ACST',
#  'ACT',
#  'ACTG',
#  'ACVA',
#  'ACWI',
#  'ACWX',
#  'ACXP',
#  'ADAG',
#  'ADAP',
#  'ADBE',
#  'ADD',
#  'ADEA',
#  'ADER',
#  'ADERU',
#  'ADERW',
#  'ADES',
#  'ADI',
#  'ADIL',
#  'ADMA',
#  'ADMP',
#  'ADN',
#  'ADNWW',
#  'ADOC',
#  'ADOCR',
#  'ADOCW',
#  'ADP',
#  'ADPT',
#  'ADSE',
#  'ADSEW',
#  'ADSK',
#  'ADTH',
#  'ADTHW',
#  'ADTN',
#  'ADTX',
#  'ADUS',
#  'ADV',
#  'ADVM',
#  'ADVWW',
#  'ADXN',
#  'AEAE',
#  'AEAEU',
#  'AEAEW',
#  'AEHL',
#  'AEHR',
#  'AEI',
#  'AEIS',
#  'AEMD',
#  'AENT',
#  'AENTW',
#  'AEP',
#  'AEPPZ',
#  'AEY',
#  'AEYE',
#  'AEZS',
#  'AFAR',
#  'AFARU',
#  'AFARW',
#  'AFBI',
#  'AFCG',
#  'AFIB',
#  'AFMD',
#  'AFRI',
#  'AFRIW',
#  'AFRM',
#  'AFYA',
#  'AGAE',
#  'AGBA',
#  'AGBAW',
#  'AGEN',
#  'AGFY',
#  'AGIL',
#  'AGILW',
#  'AGIO',
#  'AGLE',
#  'AGMH',
#  'AGNC',
#  'AGNCL',
#  'AGNCM',
#  'AGNCN',
#  'AGNCO',
#  'AGNCP',
#  'AGNG',
#  'AGRI',
#  'AGRIW',
#  'AGRX',
#  'AGYS',
#  'AGZD',
#  'AHCO',
#  'AHG',
#  'AHI',
#  'AIA',
#  'AIB',
#  'AIBBR',
#  'AIBBU',
#  'AIH',
#  'AIHS',
#  'AIMAU',
#  'AIMAW',
#  'AIMBU',
#  'AIMD',
#  'AIMDW',
#  'AIP',
#  'AIQ',
#  'AIRG',
#  'AIRR',
#  'AIRS',
#  'AIRT',
#  'AIRTP',
#  'AIXI',
#  'AKAM',
#  'AKAN',
#  'AKBA',
#  'AKLI',
#  'AKRO',
#  'AKTS',
#  'AKTX',
#  'AKU',
#  'AKYA',
#  'ALAR',
#  'ALBT',
#  'ALCO',
#  'ALCY',
#  'ALCYU',
#  'ALCYW',
#  'ALDX',
#  'ALEC',
#  'ALGM',
#  'ALGN',
#  'ALGS',
#  'ALGT',
#  'ALHC',
#  'ALIM',
#  'ALKS',
#  'ALKT',
#  'ALLK',
#  'ALLO',
#  'ALLR',
#  'ALLT',
#  'ALNY',
#  'ALOR',
#  'ALORU',
#  'ALORW',
#  'ALOT',
#  'ALPN',
#  'ALPP',
#  'ALRM',
#  'ALRN',
#  'ALRS',
#  'ALSA',
#  'ALSAR',
#  'ALSAU',
#  'ALSAW',
#  'ALT',
#  'ALTI',
#  'ALTO',
#  'ALTR',
#  'ALTU',
#  'ALTUU',
#  'ALTUW',
#  'ALTY',
#  'ALVO',
#  'ALVOW',
#  'ALVR',
#  'ALXO',
#  'ALYA',
#  'ALZN',
#  'AMAL',
#  'AMAM',
#  'AMAO',
#  'AMAOU',
#  'AMAOW',
#  'AMAT',
#  'AMBA',
#  'AMCX',
#  'AMD',
#  'AMED',
#  'AMEH',
#  'AMGN',
#  'AMID',
#  'AMKR',
#  'AMLI',
#  'AMLX',
#  'AMNB',
#  'AMOT',
#  'AMPG',
#  'AMPGW',
#  'AMPH',
#  'AMPL',
#  'AMRK',
#  'AMRN',
#  'AMRS',
#  'AMSC',
#  'AMSF',
#  'AMST',
#  'AMSWA',
#  'AMTB',
#  'AMTI',
#  'AMTX',
#  'AMWD',
#  'AMZD',
#  'AMZN',
#  'AMZU',
#  'ANAB',
#  'ANDE',
#  'ANEB',
#  'ANGH',
#  'ANGHW',
#  'ANGI',
#  'ANGL',
#  'ANGO',
#  'ANIK',
#  'ANIP',
#  'ANIX',
#  'ANNX',
#  'ANSS',
#  'ANTE',
#  'ANTX',
#  'ANY',
#  'ANZU',
#  'ANZUU',
#  'ANZUW',
#  'AOGO',
#  'AOGOU',
#  'AOGOW',
#  'AOSL',
#  'AOTG',
#  'AOUT',
#  'APA',
#  'APAC',
#  'APACU',
#  'APACW',
#  'APCX',
#  'APCXW',
#  'APDN',
#  'APEI',
#  'APGE',
#  'APGN',
#  'APGNW',
#  'API',
#  'APLD',
#  'APLM',
#  'APLMW',
#  'APLS',
#  'APLT',
#  'APM',
#  'APMI',
#  'APMIU',
#  'APMIW',
#  'APOG',
#  'APP',
#  'APPF',
#  'APPH',
#  'APPHW',
#  'APPN',
#  'APPS',
#  'APRE',
#  'APTM',
#  'APTMU',
#  'APTMW',
#  'APTO',
#  'APVO',
#  'APWC',
#  'APXI',
#  'APXIU',
#  'APXIW',
#  'APYX',
#  'AQB',
#  'AQMS',
#  'AQST',
#  'AQU',
#  'AQUNR',
#  'AQUNU',
#  'AQWA',
#  'ARAV',
#  'ARAY',
#  'ARBB',
#  'ARBE',
#  'ARBEW',
#  'ARBG',
#  'ARBGU',
#  'ARBGW',
#  'ARBK',
#  'ARBKL',
#  'ARCB',
#  'ARCC',
#  'ARCE',
#  'ARCT',
#  'ARDX',
#  'AREB',
#  'AREBW',
#  'AREC',
#  'ARGX',
#  'ARHS',
#  'ARIZ',
#  'ARIZR',
#  'ARIZU',
#  'ARIZW',
#  'ARKO',
#  'ARKOW',
#  'ARKR',
#  'ARLP',
#  'AROW',
#  'ARQQ',
#  'ARQQW',
#  'ARQT',
#  'ARRW',
#  'ARRWU',
#  'ARRWW',
#  'ARRY',
#  'ARTE',
#  'ARTEU',
#  'ARTEW',
#  'ARTL',
#  'ARTLW',
#  'ARTNA',
#  'ARTW',
#  'ARVL',
#  'ARVN',
#  'ARVR',
#  'ARWR',
#  'ARYD',
#  'ASCA',
#  'ASCAR',
#  'ASCAU',
#  'ASCAW',
#  'ASCB',
#  'ASCBR',
#  'ASCBU',
#  'ASCBW',
#  'ASET',
#  'ASLE',
#  'ASLN',
#  'ASMB',
#  'ASML',
#  'ASND',
#  'ASNS',
#  'ASO',
#  'ASPA',
#  'ASPAU',
#  'ASPAW',
#  'ASPI',
#  'ASPS',
#  'ASRT',
#  'ASRV',
#  'ASST',
#  'ASTC',
#  'ASTE',
#  'ASTI',
#  'ASTL',
#  'ASTLW',
#  'ASTR',
#  'ASTS',
#  'ASTSW',
#  'ASUR',
#  'ASYS',
#  'ATAI',
#  'ATAK',
#  'ATAKR',
#  'ATAKU',
#  'ATAKW',
#  'ATAT',
#  'ATCOL',
#  'ATEC',
#  'ATER',
#  'ATEX',
#  'ATHA',
#  'ATHE',
#  'ATHX',
#  'ATIF',
#  'ATLC',
#  'ATLCL',
#  'ATLCP',
#  'ATLO',
#  'ATLX',
#  'ATMC',
#  'ATMCR',
#  'ATMCU',
#  'ATMCW',
#  'ATMV',
#  'ATMVR',
#  'ATMVU',
#  'ATNF',
#  'ATNFW',
#  'ATNI',
#  'ATOM',
#  'ATOS',
#  'ATRA',
#  'ATRC',
#  'ATRI',
#  'ATRO',
#  'ATSG',
#  'ATVI',
#  'ATXG',
#  'ATXI',
#  'ATXS',
#  'AUBN',
#  'AUDC',
#  'AUGX',
#  'AUID',
#  'AUPH',
#  'AUR',
#  'AURA',
#  'AURC',
#  'AURCU',
#  'AURCW',
#  'AUROW',
#  'AUTL',
#  'AUUD',
#  'AUUDW',
#  'AUVI',
#  'AUVIP',
#  'AVAH',
#  'AVAV',
#  'AVDL',
#  'AVDX',
#  'AVGO',
#  'AVGR',
#  'AVHI',
#  'AVHIU',
#  'AVHIW',
#  'AVID',
#  'AVIR',
#  'AVNW',
#  'AVO',
#  'AVPT',
#  'AVPTW',
#  'AVRO',
#  'AVT',
#  'AVTA',
#  'AVTE',
#  'AVTX',
#  'AVXL',
#  'AWH',
#  'AWIN',
#  'AWINW',
#  'AWRE',
#  'AXDX',
#  'AXGN',
#  'AXLA',
#  'AXNX',
#  'AXON',
#  'AXSM',
#  'AXTI',
#  'AY',
#  'AYRO',
#  'AYTU',
#  'AZ',
#  'AZN',
#  'AZPN',
#  'AZTA',
#  'AZYO',
#  'BABX',
#  'BACK',
#  'BAER',
#  'BAERW',
#  'BAFN',
#  'BAND',
#  'BANF',
#  'BANFP',
#  'BANL',
#  'BANR',
#  'BANX',
#  'BAOS',
#  'BASE',
#  'BATRA',
#  'BATRK',
#  'BBCP',
#  'BBGI',
#  'BBH',
#  'BBIO',
#  'BBLG',
#  'BBLGW',
#  'BBSI',
#  'BCAB',
#  'BCAL',
#  'BCAN',
#  'BCBP',
#  'BCDA',
#  'BCDAW',
#  'BCEL',
#  'BCLI',
#  'BCML',
#  'BCOV',
#  'BCOW',
#  'BCPC',
#  'BCRX',
#  'BCSA',
#  'BCSAU',
#  'BCSAW',
#  'BCTX',
#  'BCTXW',
#  'BCYC',
#  'BDGS',
#  'BDRX',
#  'BDSX',
#  'BDTX',
#  'BEAM',
#  'BEAT',
#  'BEATW',
#  'BECN',
#  'BEEM',
#  'BEEMW',
#  'BELFA',
#  'BELFB',
#  'BENF',
#  'BENFW',
#  'BFC',
#  'BFI',
#  'BFIIW',
#  'BFIN',
#  'BFIT',
#  'BFRG',
#  'BFRGW',
#  'BFRI',
#  'BFRIW',
#  'BFST',
#  'BGC',
#  'BGFV',
#  'BGLC',
#  'BGNE',
#  'BGRN',
#  'BGXX',
#  'BHAC',
#  'BHACU',
#  'BHACW',
#  'BHAT',
#  'BHF',
#  'BHFAL',
#  'BHFAM',
#  'BHFAN',
#  'BHFAO',
#  'BHFAP',
#  'BHRB',
#  'BIAF',
#  'BIAFW',
#  'BIB',
#  'BIDU',
#  'BIGB',
#  'BIGC',
#  'BIGT',
#  'BIIB',
#  'BILI',
#  'BIMI',
#  'BIOC',
#  'BIOL',
#  'BIOR',
#  'BIOS',
#  'BIOSU',
#  'BIOSW',
#  'BIOX',
#  'BIRD',
#  'BIS',
#  'BITF',
#  'BITS',
#  'BIVI',
#  'BJDX',
#  'BJK',
#  'BJRI',
#  'BKCC',
#  'BKCH',
#  'BKIV',
#  'BKNG',
#  'BKR',
#  'BKSC',
#  'BKWO',
#  'BKYI',
#  'BL',
#  'BLAC',
#  'BLACR',
#  'BLACU',
#  'BLACW',
#  'BLBD',
#  'BLBX',
#  'BLCN',
#  'BLDE',
#  'BLDEW',
#  'BLDP',
#  'BLEU',
#  'BLEUR',
#  'BLEUU',
#  'BLEUW',
#  'BLFS',
#  'BLFY',
#  'BLIN',
#  'BLKB',
#  'BLLD',
#  'BLMN',
#  'BLNK',
#  'BLPH',
#  'BLRX',
#  'BLTE',
#  'BLUE',
#  'BLZE',
#  'BMBL',
#  'BMEA',
#  'BMR',
#  'BMRA',
#  'BMRC',
#  'BMRN',
#  'BND',
#  'BNDW',
#  'BNDX',
#  'BNGO',
#  'BNGOW',
#  'BNIX',
#  'BNIXR',
#  'BNIXW',
#  'BNMV',
#  'BNOX',
#  'BNR',
#  'BNRG',
#  'BNTC',
#  'BNTX',
#  'BOCN',
#  'BOCNU',
#  'BOCNW',
#  'BOF',
#  'BOKF',
#  'BOLT',
#  'BON',
#  'BOOM',
#  'BOSC',
#  'BOTJ',
#  'BOTZ',
#  'BOWNU',
#  'BOXL',
#  'BPMC',
#  'BPOP',
#  'BPOPM',
#  'BPRN',
#  'BPTH',
#  'BPTS',
#  'BPYPM',
#  'BPYPN',
#  'BPYPO',
#  'BPYPP',
#  'BRAC',
#  'BRACR',
#  'BRACU',
#  'BRAG',
#  'BREA',
#  'BREZ',
#  'BREZR',
#  'BREZW',
#  'BRFH',
#  'BRID',
#  'BRKH',
#  'BRKHU',
#  'BRKHW',
#  'BRKL',
#  'BRKR',
#  'BRLI',
#  'BRLIR',
#  'BRLIU',
#  'BRLIW',
#  'BRLT',
#  'BRNY',
#  'BROG',
#  'BROGW',
#  'BRP',
#  'BRQS',
#  'BRSH',
#  'BRSHW',
#  'BRTX',
#  'BRY',
#  'BRZE',
#  'BSBK',
#  'BSCN',
#  'BSCO',
#  'BSCP',
#  'BSCQ',
#  'BSCR',
#  'BSCS',
#  'BSCT',
#  'BSCU',
#  'BSCV',
#  'BSCW',
#  'BSET',
#  'BSFC',
#  'BSGM',
#  'BSJN',
#  'BSJO',
#  'BSJP',
#  'BSJQ',
#  'BSJR',
#  'BSJS',
#  'BSJT',
#  'BSJU',
#  'BSMN',
#  'BSMO',
#  'BSMP',
#  'BSMQ',
#  'BSMR',
#  'BSMS',
#  'BSMT',
#  'BSMU',
#  'BSMV',
#  'BSMW',
#  'BSQR',
#  'BSRR',
#  'BSVN',
#  'BSVO',
#  'BSY',
#  'BTAI',
#  'BTB',
#  'BTBD',
#  'BTBDW',
#  'BTBT',
#  'BTCS',
#  'BTCY',
#  'BTDR',
#  'BTEC',
#  'BTF',
#  'BTM',
#  'BTMD',
#  'BTMWW',
#  'BTOG',
#  'BTTX',
#  'BTWN',
#  'BTWNU',
#  'BTWNW',
#  'BUG',
#  'BUJAU',
#  'BULD',
#  'BUSE',
#  'BVS',
#  'BVXV',
#  'BWAQ',
#  'BWAQR',
#  'BWAQU',
#  'BWAQW',
#  'BWAY',
#  'BWB',
#  'BWBBP',
#  'BWC',
#  'BWCAU',
#  'BWCAW',
#  'BWEN',
#  'BWFG',
#  'BWMN',
#  'BWMX',
#  'BWV',
#  'BXRX',
#  'BYFC',
#  'BYND',
#  'BYNO',
#  'BYNOU',
#  'BYNOW',
#  'BYOB',
#  'BYRN',
#  'BYSI',
#  'BYTS',
#  'BYTSU',
#  'BYTSW',
#  'BZ',
#  'BZFD',
#  'BZFDW',
#  'BZUN',
#  'CAAS',
#  'CABA',
#  'CAC',
#  'CACC',
#  'CACG',
#  'CACO',
#  'CADL',
#  'CAFG',
#  'CAKE',
#  'CALB',
#  'CALC',
#  'CALM',
#  'CALT',
#  'CALY',
#  'CAMP',
#  'CAMT',
#  'CAN',
#  'CAPR',
#  'CAR',
#  'CARA',
#  'CARE',
#  'CARG',
#  'CARM',
#  'CARV',
#  'CARZ',
#  'CASA',
#  'CASH',
#  'CASI',
#  'CASS',
#  'CASY',
#  'CATC',
#  'CATH',
#  'CATY',
#  'CBAN',
#  'CBAT',
#  'CBAY',
#  'CBFV',
#  'CBIO',
#  'CBNK',
#  'CBRG',
#  'CBRGU',
#  'CBRGW',
#  'CBRL',
#  'CBSH',
#  'CBUS',
#  'CCAI',
#  'CCAIU',
#  'CCAIW',
#  'CCAP',
#  'CCB',
#  'CCBG',
#  'CCCC',
#  'CCCS',
#  'CCD',
#  'CCEP',
#  'CCLD',
#  'CCLDO',
#  'CCLDP',
#  'CCLP',
#  'CCNE',
#  'CCNEP',
#  'CCOI',
#  'CCRN',
#  'CCSI',
#  'CCSO',
#  'CCTS',
#  'CCTSU',
#  'CCTSW',
#  'CD',
#  'CDAQ',
#  'CDAQU',
#  'CDAQW',
#  'CDC',
#  'CDIO',
#  'CDIOW',
#  'CDL',
#  'CDLX',
#  'CDMO',
#  'CDNA',
#  'CDNS',
#  'CDRO',
#  'CDROW',
#  'CDTX',
#  'CDW',
#  'CDXC',
#  'CDXS',
#  'CDZI',
#  'CDZIP',
#  'CEAD',
#  'CEADW',
#  'CECO',
#  'CEFA',
#  'CEG',
#  'CELC',
#  'CELH',
#  'CELL',
#  'CELU',
#  'CELUW',
#  'CELZ',
#  'CENN',
#  'CENT',
#  'CENTA',
#  'CENX',
#  'CERE',
#  'CERS',
#  'CERT',
#  'CETU',
#  'CETUR',
#  'CETUU',
#  'CETUW',
#  'CETX',
#  'CETXP',
#  'CETY',
#  'CEVA',
#  'CFA',
#  'CFB',
#  'CFBK',
#  'CFFE',
#  'CFFEU',
#  'CFFEW',
#  'CFFI',
#  'CFFN',
#  'CFFS',
#  'CFFSU',
#  'CFFSW',
#  'CFIV',
#  'CFIVU',
#  'CFIVW',
#  'CFLT',
#  'CFMS',
#  'CFO',
#  'CFRX',
#  'CFSB',
#  'CG',
#  'CGABL',
#  'CGBD',
#  'CGC',
#  'CGEM',
#  'CGEN',
#  'CGNT',
#  'CGNX',
#  'CGO',
#  'CGRN',
#  'CGTX',
#  'CHB',
#  'CHCI',
#  'CHCO',
#  'CHDN',
#  'CHEA',
#  'CHEAU',
#  'CHEAW',
#  'CHEF',
#  'CHEK',
#  'CHI',
#  'CHK',
#  'CHKEL',
#  'CHKEW',
#  'CHKEZ',
#  'CHKP',
#  'CHMG',
#  'CHNA',
#  'CHNR',
#  'CHPS',
#  'CHRD',
#  'CHRS',
#  'CHRW',
#  'CHSCL',
#  'CHSCM',
#  'CHSCN',
#  'CHSCO',
#  'CHSCP',
#  'CHSN',
#  ...]

# %%
tickers_nasdaq = si.tickers_nasdaq()

# %%
nasdaq_info_dict = dict()

# %%
aapl = yf.Ticker('AAPL')

# %%
len(aapl.info.keys())
# Out:
# 121

# %%
si.get_quote_table("aapl", dict_result=True)
# Out:
# /Users/mandu/opt/anaconda3/lib/python3.9/site-packages/yahoo_fin/stock_info.py:295: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = tables[0].append(tables[1])
# /Users/mandu/opt/anaconda3/lib/python3.9/site-packages/yahoo_fin/stock_info.py:302: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(quote_price)
# {'1y Target Est': 174.36,
#  '52 Week Range': '124.17 - 198.23',
#  'Ask': '0.00 x 1000',
#  'Avg. Volume': 56926808.0,
#  'Beta (5Y Monthly)': 1.29,
#  'Bid': '0.00 x 800',
#  "Day's Range": '194.15 - 196.62',
#  'EPS (TTM)': 5.89,
#  'Earnings Date': 'Aug 03, 2023',
#  'Ex-Dividend Date': 'May 12, 2023',
#  'Forward Dividend & Yield': '0.96 (0.50%)',
#  'Market Cap': '3.08T',
#  'Open': 194.67,
#  'PE Ratio (TTM)': 33.25,
#  'Previous Close': 193.22,
#  'Quote Price': 195.8300018310547,
#  'Volume': 46977437.0}

# %%
get_data("AAPL")
# Out:
#                   open        high         low       close    adjclose  \
# 1980-12-12    0.128348    0.128906    0.128348    0.128348    0.100764
# 1980-12-15    0.122210    0.122210    0.121652    0.121652    0.095508
# 1980-12-16    0.113281    0.113281    0.112723    0.112723    0.088498
# 1980-12-17    0.115513    0.116071    0.115513    0.115513    0.090688
# 1980-12-18    0.118862    0.119420    0.118862    0.118862    0.093317
# ...                ...         ...         ...         ...         ...
# 2023-07-24  193.410004  194.910004  192.250000  192.750000  192.750000
# 2023-07-25  193.330002  194.440002  192.919998  193.619995  193.619995
# 2023-07-26  193.669998  195.639999  193.320007  194.500000  194.500000
# 2023-07-27  196.020004  197.199997  192.550003  193.220001  193.220001
# 2023-07-28  194.669998  196.630005  194.139999  195.830002  195.830002
#
#                volume ticker
# 1980-12-12  469033600   AAPL
# 1980-12-15  175884800   AAPL
# 1980-12-16  105728000   AAPL
# 1980-12-17   86441600   AAPL
# 1980-12-18   73449600   AAPL
# ...               ...    ...
# 2023-07-24   45377800   AAPL
# 2023-07-25   37283200   AAPL
# 2023-07-26   47471900   AAPL
# 2023-07-27   47460200   AAPL
# 2023-07-28   48254600   AAPL
#
# [10746 rows x 7 columns]

# %%
import yfinance as yf
from concurrent.futures import ThreadPoolExecutor


def get_stock_info(ticker, index):
    print(f"Fetching data for {ticker} (Data #{index + 1})...")
    return ticker, yf.Ticker(ticker).info

nasdaq_info_dict = {}

# ThreadPoolExecutor를 사용하여 병렬 처리
with ThreadPoolExecutor() as executor:
    results = executor.map(get_stock_info, tickers_nasdaq, range(len(tickers_nasdaq)))

# 결과를 딕셔너리에 저장
for index, (ticker, info) in enumerate(results):
    nasdaq_info_dict[ticker] = info
# Out:
# Fetching data for AACG (Data #1)...
# Fetching data for AACI (Data #2)...
# Fetching data for AACIU (Data #3)...
# Fetching data for AACIW (Data #4)...
# Fetching data for AADI (Data #5)...
# Fetching data for AADR (Data #6)...
# Fetching data for AAL (Data #7)...
# Fetching data for AAME (Data #8)...
# Fetching data for AAOI (Data #9)...
# Fetching data for AAON (Data #10)...
# Fetching data for AAPB (Data #11)...
# Fetching data for AAPD (Data #12)...
# Fetching data for AAPL (Data #13)...
# Fetching data for AAPU (Data #14)...
# Fetching data for AAXJ (Data #15)...
# Fetching data for ABCB (Data #16)...
# Fetching data for ABCL (Data #17)...
# Fetching data for ABCM (Data #18)...
# Fetching data for ABEO (Data #19)...
# Fetching data for ABIO (Data #20)...
# Fetching data for ABL (Data #21)...
# Fetching data for ABLLW (Data #22)...
# Fetching data for ABNB (Data #23)...
# Fetching data for ABOS (Data #24)...
# Fetching data for ABSI (Data #25)...
# Fetching data for ABUS (Data #26)...
# Fetching data for ABVC (Data #27)...
# Fetching data for ACAB (Data #28)...
# Fetching data for ACABU (Data #29)...
# Fetching data for ACABW (Data #30)...
# Fetching data for ACAC (Data #31)...
# Fetching data for ACACU (Data #32)...
# Fetching data for ACACW (Data #33)...
# Fetching data for ACAD (Data #34)...
# Fetching data for ACAH (Data #35)...
# Fetching data for ACAHU (Data #36)...
# Fetching data for ACAHW (Data #37)...
# Fetching data for ACAX (Data #38)...
# Fetching data for ACAXR (Data #39)...
# Fetching data for ACAXU (Data #40)...
# Fetching data for ACAXW (Data #41)...
# Fetching data for ACB (Data #42)...
# Fetching data for ACBA (Data #43)...
# Fetching data for ACBAU (Data #44)...
# Fetching data for ACBAW (Data #45)...
# Fetching data for ACCD (Data #46)...
# Fetching data for ACDC (Data #47)...
# Fetching data for ACDCW (Data #48)...
# Fetching data for ACER (Data #49)...
# Fetching data for ACET (Data #50)...
# Fetching data for ACGL (Data #51)...
# Fetching data for ACGLN (Data #52)...
# Fetching data for ACGLO (Data #53)...
# Fetching data for ACGN (Data #54)...
# Fetching data for ACHC (Data #55)...
# Fetching data for ACHL (Data #56)...
# Fetching data for ACHV (Data #57)...
# Fetching data for ACIU (Data #58)...
# Fetching data for ACIW (Data #59)...
# Fetching data for ACLS (Data #60)...
# Fetching data for ACLX (Data #61)...
# Fetching data for ACMR (Data #62)...
# Fetching data for ACNB (Data #63)...
# Fetching data for ACNT (Data #64)...
# Fetching data for ACON (Data #65)...
# Fetching data for ACONW (Data #66)...
# Fetching data for ACOR (Data #67)...
# Fetching data for ACRS (Data #68)...
# Fetching data for ACRV (Data #69)...
# Fetching data for ACRX (Data #70)...
# Fetching data for ACST (Data #71)...
# Fetching data for ACT (Data #72)...
# Fetching data for ACTG (Data #73)...
# Fetching data for ACVA (Data #74)...
# Fetching data for ACWI (Data #75)...
# Fetching data for ACWX (Data #76)...
# Fetching data for ACXP (Data #77)...Fetching data for ADAG (Data #78)...
#
# Fetching data for ADAP (Data #79)...
# Fetching data for ADBE (Data #80)...
# Fetching data for ADD (Data #81)...
# Fetching data for ADEA (Data #82)...
# Fetching data for ADER (Data #83)...
# Fetching data for ADERU (Data #84)...
# Fetching data for ADERW (Data #85)...
# Fetching data for ADES (Data #86)...
# Fetching data for ADI (Data #87)...
# Fetching data for ADIL (Data #88)...
# Fetching data for ADMA (Data #89)...
# Fetching data for ADMP (Data #90)...
# Fetching data for ADN (Data #91)...
# Fetching data for ADNWW (Data #92)...
# Fetching data for ADOC (Data #93)...
# Fetching data for ADOCR (Data #94)...
# Fetching data for ADOCW (Data #95)...
# Fetching data for ADP (Data #96)...
# Fetching data for ADPT (Data #97)...
# Fetching data for ADSE (Data #98)...
# Fetching data for ADSEW (Data #99)...
# Fetching data for ADSK (Data #100)...
# Fetching data for ADTH (Data #101)...Fetching data for ADTHW (Data #102)...
#
# Fetching data for ADTN (Data #103)...
# Fetching data for ADTX (Data #104)...
# Fetching data for ADUS (Data #105)...
# Fetching data for ADV (Data #106)...
# Fetching data for ADVM (Data #107)...
# Fetching data for ADVWW (Data #108)...
# Fetching data for ADXN (Data #109)...
# Fetching data for AEAE (Data #110)...
# Fetching data for AEAEU (Data #111)...
# Fetching data for AEAEW (Data #112)...
# Fetching data for AEHL (Data #113)...
# Fetching data for AEHR (Data #114)...
# Fetching data for AEI (Data #115)...
# Fetching data for AEIS (Data #116)...
# Fetching data for AEMD (Data #117)...Fetching data for AENT (Data #118)...
#
# Fetching data for AENTW (Data #119)...
# Fetching data for AEP (Data #120)...
# Fetching data for AEPPZ (Data #121)...
# Fetching data for AEY (Data #122)...
# Fetching data for AEYE (Data #123)...
# Fetching data for AEZS (Data #124)...
# Fetching data for AFAR (Data #125)...
# Fetching data for AFARU (Data #126)...
# Fetching data for AFARW (Data #127)...
# Fetching data for AFBI (Data #128)...
# Fetching data for AFCG (Data #129)...
# Fetching data for AFIB (Data #130)...
# Fetching data for AFMD (Data #131)...
# Fetching data for AFRI (Data #132)...
# Fetching data for AFRIW (Data #133)...
# Fetching data for AFRM (Data #134)...
# Fetching data for AFYA (Data #135)...
# Fetching data for AGAE (Data #136)...
# Fetching data for AGBA (Data #137)...
# Fetching data for AGBAW (Data #138)...
# Fetching data for AGEN (Data #139)...
# Fetching data for AGFY (Data #140)...
# Fetching data for AGIL (Data #141)...
# Fetching data for AGILW (Data #142)...
# Fetching data for AGIO (Data #143)...
# Fetching data for AGLE (Data #144)...Fetching data for AGMH (Data #145)...
#
# Fetching data for AGNC (Data #146)...
# Fetching data for AGNCL (Data #147)...
# Fetching data for AGNCM (Data #148)...
# Fetching data for AGNCN (Data #149)...
# Fetching data for AGNCO (Data #150)...
# Fetching data for AGNCP (Data #151)...
# Fetching data for AGNG (Data #152)...
# Fetching data for AGRI (Data #153)...
# Fetching data for AGRIW (Data #154)...
# Fetching data for AGRX (Data #155)...
# Fetching data for AGYS (Data #156)...
# Fetching data for AGZD (Data #157)...
# Fetching data for AHCO (Data #158)...
# Fetching data for AHG (Data #159)...
# Fetching data for AHI (Data #160)...
# Fetching data for AIA (Data #161)...
# Fetching data for AIB (Data #162)...
# Fetching data for AIBBR (Data #163)...
# Fetching data for AIBBU (Data #164)...
# Fetching data for AIH (Data #165)...Fetching data for AIHS (Data #166)...
#
# Fetching data for AIMAU (Data #167)...
# Fetching data for AIMAW (Data #168)...
# Fetching data for AIMBU (Data #169)...
# Fetching data for AIMD (Data #170)...
# Fetching data for AIMDW (Data #171)...
# Fetching data for AIP (Data #172)...
# Fetching data for AIQ (Data #173)...
# Fetching data for AIRG (Data #174)...
# Fetching data for AIRR (Data #175)...
# Fetching data for AIRS (Data #176)...
# Fetching data for AIRT (Data #177)...
# Fetching data for AIRTP (Data #178)...
# Fetching data for AIXI (Data #179)...
# Fetching data for AKAM (Data #180)...
# Fetching data for AKAN (Data #181)...Fetching data for AKBA (Data #182)...
# Fetching data for AKLI (Data #183)...
#
# Fetching data for AKRO (Data #184)...
# Fetching data for AKTS (Data #185)...
# Fetching data for AKTX (Data #186)...
# Fetching data for AKU (Data #187)...
# Fetching data for AKYA (Data #188)...
# Fetching data for ALAR (Data #189)...
# Fetching data for ALBT (Data #190)...
# Fetching data for ALCO (Data #191)...
# Fetching data for AMZU (Data #272)...
# Fetching data for ANAB (Data #273)...
# Fetching data for ANDE (Data #274)...
# Fetching data for ANEB (Data #275)...
# Fetching data for ANGH (Data #276)...
# Fetching data for ANGHW (Data #277)...
# Fetching data for ANGI (Data #278)...
# Fetching data for ANGL (Data #279)...
# Fetching data for ANGO (Data #280)...
# Fetching data for ANIK (Data #281)...
# Fetching data for ANIP (Data #282)...
# Fetching data for ANIX (Data #283)...
# Fetching data for ANNX (Data #284)...
# Fetching data for ANSS (Data #285)...
# Fetching data for ANTE (Data #286)...
# Fetching data for ANTX (Data #287)...
# Fetching data for ANY (Data #288)...
# Fetching data for ANZU (Data #289)...
# Fetching data for ANZUU (Data #290)...
# Fetching data for ANZUW (Data #291)...
# Fetching data for AOGO (Data #292)...
# Fetching data for AOGOU (Data #293)...
# Fetching data for AOGOW (Data #294)...
# Fetching data for AOSL (Data #295)...
# Fetching data for AOTG (Data #296)...
# Fetching data for AOUT (Data #297)...
# Fetching data for APA (Data #298)...
# Fetching data for APAC (Data #299)...
# Fetching data for APACU (Data #300)...
# Fetching data for APACW (Data #301)...
# Fetching data for APCX (Data #302)...
# Fetching data for APCXW (Data #303)...
# Fetching data for APDN (Data #304)...
# Fetching data for APEI (Data #305)...
# Fetching data for APGE (Data #306)...
# Fetching data for APGN (Data #307)...
# Fetching data for APGNW (Data #308)...
# Fetching data for API (Data #309)...
# Fetching data for APLD (Data #310)...
# Fetching data for APLM (Data #311)...
# Fetching data for APLMW (Data #312)...
# Fetching data for APLS (Data #313)...
# Fetching data for APLT (Data #314)...
# Fetching data for APM (Data #315)...
# Fetching data for APMI (Data #316)...
# Fetching data for APMIU (Data #317)...
# Fetching data for APMIW (Data #318)...
# Fetching data for APOG (Data #319)...
# Fetching data for APP (Data #320)...
# Fetching data for APPF (Data #321)...
# Fetching data for APPH (Data #322)...
# Fetching data for APPHW (Data #323)...Fetching data for APPN (Data #324)...
#
# Fetching data for APPS (Data #325)...
# Fetching data for APRE (Data #326)...
# Fetching data for APTM (Data #327)...
# Fetching data for APTMU (Data #328)...
# Fetching data for APTMW (Data #329)...
# Fetching data for APTO (Data #330)...
# Fetching data for APVO (Data #331)...
# Fetching data for APWC (Data #332)...
# Fetching data for APXI (Data #333)...
# Fetching data for APXIU (Data #334)...Fetching data for APXIW (Data #335)...
#
# Fetching data for APYX (Data #336)...
# Fetching data for AQB (Data #337)...
# Fetching data for AQMS (Data #338)...
# Fetching data for AQST (Data #339)...
# Fetching data for AQU (Data #340)...
# Fetching data for AQUNR (Data #341)...
# Fetching data for AQUNU (Data #342)...
# Fetching data for AQWA (Data #343)...
# Fetching data for ARAV (Data #344)...
# Fetching data for ARAY (Data #345)...
# Fetching data for ARBB (Data #346)...
# Fetching data for ARBE (Data #347)...
# Fetching data for ARBEW (Data #348)...
# Fetching data for ARBG (Data #349)...
# Fetching data for ARBGU (Data #350)...
# Fetching data for ARBGW (Data #351)...
# Fetching data for ARBK (Data #352)...
# Fetching data for ARBKL (Data #353)...
# Fetching data for ATEC (Data #433)...
# Fetching data for ATER (Data #434)...
# Fetching data for ATEX (Data #435)...
# Fetching data for ATHA (Data #436)...
# Fetching data for ATHE (Data #437)...
# Fetching data for ATHX (Data #438)...
# Fetching data for ATIF (Data #439)...
# Fetching data for ATLC (Data #440)...
# Fetching data for ATLCL (Data #441)...
# Fetching data for ATLCP (Data #442)...
# Fetching data for ATLO (Data #443)...
# Fetching data for ATLX (Data #444)...
# Fetching data for ATMC (Data #445)...
# Fetching data for ATMCR (Data #446)...
# Fetching data for ATMCU (Data #447)...
# Fetching data for ATMCW (Data #448)...
# Fetching data for ATMV (Data #449)...Fetching data for ATMVR (Data #450)...
#
# Fetching data for ATMVU (Data #451)...
# Fetching data for ATNF (Data #452)...
# Fetching data for ATNFW (Data #453)...
# Fetching data for ATNI (Data #454)...
# Fetching data for ATOM (Data #455)...
# Fetching data for ATOS (Data #456)...
# Fetching data for ATRA (Data #457)...
# Fetching data for ATRC (Data #458)...
# Fetching data for ATRI (Data #459)...
# Fetching data for ATRO (Data #460)...
# Fetching data for ATSG (Data #461)...
# Fetching data for ATVI (Data #462)...
# Fetching data for ATXG (Data #463)...
# Fetching data for ATXI (Data #464)...
# Fetching data for ATXS (Data #465)...
# Fetching data for AUBN (Data #466)...
# Fetching data for AUDC (Data #467)...
# Fetching data for AUGX (Data #468)...
# Fetching data for AUID (Data #469)...
# Fetching data for AUPH (Data #470)...
# Fetching data for AUR (Data #471)...
# Fetching data for AURA (Data #472)...
# Fetching data for AURC (Data #473)...
# Fetching data for AURCU (Data #474)...
# Fetching data for AURCW (Data #475)...
# Fetching data for AUROW (Data #476)...
# Fetching data for AUTL (Data #477)...
# Fetching data for AUUD (Data #478)...
# Fetching data for AUUDW (Data #479)...
# Fetching data for AUVI (Data #480)...
# Fetching data for AUVIP (Data #481)...
# Fetching data for AVAH (Data #482)...
# Fetching data for AVAV (Data #483)...
# Fetching data for AVDL (Data #484)...
# Fetching data for AVDX (Data #485)...
# Fetching data for AVGO (Data #486)...
# Fetching data for AVGR (Data #487)...
# Fetching data for AVHI (Data #488)...
# Fetching data for AVHIU (Data #489)...
# Fetching data for AVHIW (Data #490)...
# Fetching data for AVID (Data #491)...
# Fetching data for AVIR (Data #492)...
# Fetching data for AVNW (Data #493)...
# Fetching data for AVO (Data #494)...
# Fetching data for AVPT (Data #495)...
# Fetching data for AVPTW (Data #496)...
# Fetching data for AVRO (Data #497)...
# Fetching data for AVT (Data #498)...
# Fetching data for AVTA (Data #499)...
# Fetching data for AVTE (Data #500)...Fetching data for AVTX (Data #501)...
# Fetching data for AVXL (Data #502)...
#
# Fetching data for AWH (Data #503)...
# Fetching data for AWIN (Data #504)...
# Fetching data for AWINW (Data #505)...
# Fetching data for AWRE (Data #506)...
# Fetching data for AXDX (Data #507)...
# Fetching data for AXGN (Data #508)...
# Fetching data for AXLA (Data #509)...
# Fetching data for AXNX (Data #510)...
# Fetching data for AXON (Data #511)...
# Fetching data for AXSM (Data #512)...
# Fetching data for CHSCM (Data #996)...
# Fetching data for CHSCN (Data #997)...
# Fetching data for CHSCO (Data #998)...
# Fetching data for CHSCP (Data #999)...
# Fetching data for CHSN (Data #1000)...
# Fetching data for CHTR (Data #1001)...
# Fetching data for CHUY (Data #1002)...
# Fetching data for CHW (Data #1003)...
# Fetching data for CHX (Data #1004)...
# Fetching data for CHY (Data #1005)...
# Fetching data for CIBR (Data #1006)...
# Fetching data for CID (Data #1007)...
# Fetching data for CIFR (Data #1008)...
# Fetching data for CIFRW (Data #1009)...
# Fetching data for CIGI (Data #1010)...
# Fetching data for CIL (Data #1011)...
# Fetching data for CINF (Data #1012)...
# Fetching data for CING (Data #1013)...
# Fetching data for CINGW (Data #1014)...
# Fetching data for CIRC (Data #1015)...
# Fetching data for CISO (Data #1016)...
# Fetching data for CISS (Data #1017)...
# Fetching data for CITE (Data #1018)...
# Fetching data for CITEU (Data #1019)...
# Fetching data for CITEW (Data #1020)...
# Fetching data for CIVB (Data #1021)...
# Fetching data for CIZ (Data #1022)...
# Fetching data for CIZN (Data #1023)...
# Fetching data for CJET (Data #1024)...
# Fetching data for CJJD (Data #1025)...
# Fetching data for CKPT (Data #1026)...
# Fetching data for CLAR (Data #1027)...
# Fetching data for CLAY (Data #1028)...
# Fetching data for CLAYU (Data #1029)...
# Fetching data for CLAYW (Data #1030)...
# Fetching data for CLBK (Data #1031)...
# Fetching data for CLBT (Data #1032)...
# Fetching data for CLBTW (Data #1033)...
# Fetching data for CLDX (Data #1034)...
# Fetching data for CLEU (Data #1035)...
# Fetching data for CLFD (Data #1036)...
# Fetching data for CLGN (Data #1037)...
# Fetching data for CLIN (Data #1038)...
# Fetching data for CLINR (Data #1039)...
# Fetching data for CLINU (Data #1040)...
# Fetching data for CLINW (Data #1041)...
# Fetching data for CLIR (Data #1042)...
# Fetching data for CLLS (Data #1043)...
# Fetching data for CLMB (Data #1044)...
# Fetching data for CLMT (Data #1045)...
# Fetching data for CLNE (Data #1046)...
# Fetching data for CLNN (Data #1047)...
# Fetching data for CLNNW (Data #1048)...
# Fetching data for CLOA (Data #1049)...
# Fetching data for CLOE (Data #1050)...
# Fetching data for CLOER (Data #1051)...
# Fetching data for CLOEU (Data #1052)...
# Fetching data for CLOU (Data #1053)...
# Fetching data for CLOV (Data #1054)...
# Fetching data for CLPS (Data #1055)...
# Fetching data for CLPT (Data #1056)...
# Fetching data for CLRB (Data #1057)...
# Fetching data for CLRC (Data #1058)...
# Fetching data for CLRCR (Data #1059)...
# Fetching data for CLRCU (Data #1060)...
# Fetching data for CLRCW (Data #1061)...
# Fetching data for CLRG (Data #1062)...
# Fetching data for CLRO (Data #1063)...
# Fetching data for CLSA (Data #1064)...
# Fetching data for CLSC (Data #1065)...
# Fetching data for CLSD (Data #1066)...
# Fetching data for CLSK (Data #1067)...
# Fetching data for CLSM (Data #1068)...
# Fetching data for CLST (Data #1069)...
# Fetching data for CLVR (Data #1070)...
# Fetching data for CLVRW (Data #1071)...
# Fetching data for CLWT (Data #1072)...
# Fetching data for CMAX (Data #1073)...
# Fetching data for CMAXW (Data #1074)...
# Fetching data for CMBM (Data #1075)...
# Fetching data for CMCA (Data #1076)...
# Fetching data for CMCAU (Data #1077)...
# Fetching data for CMCAW (Data #1078)...
# Fetching data for CMCO (Data #1079)...
# Fetching data for CMCSA (Data #1080)...
# Fetching data for CMCT (Data #1081)...
# Fetching data for CME (Data #1082)...
# Fetching data for CMLS (Data #1083)...
# Fetching data for CMMB (Data #1084)...
# Fetching data for CMND (Data #1085)...
# Fetching data for CMPO (Data #1086)...
# Fetching data for CMPOW (Data #1087)...
# Fetching data for CMPR (Data #1088)...
# Fetching data for CMPS (Data #1089)...Fetching data for CMPX (Data #1090)...
#
# Fetching data for CMRA (Data #1091)...
# Fetching data for CMRAW (Data #1092)...Fetching data for CMRX (Data #1093)...
#
# Fetching data for CMTL (Data #1094)...
# Fetching data for CNCR (Data #1095)...
# Fetching data for CNDT (Data #1096)...
# Fetching data for CNET (Data #1097)...
# Fetching data for CNEY (Data #1098)...
# Fetching data for CNFR (Data #1099)...
# Fetching data for CNFRL (Data #1100)...
# Fetching data for CNGL (Data #1101)...
# Fetching data for CNGLU (Data #1102)...
# Fetching data for CNGLW (Data #1103)...
# Fetching data for CNOB (Data #1104)...
# Fetching data for CNOBP (Data #1105)...
# Fetching data for CNSL (Data #1106)...
# Fetching data for CNSP (Data #1107)...
# Fetching data for CNTA (Data #1108)...
# Fetching data for CNTB (Data #1109)...
# Fetching data for CNTG (Data #1110)...
# Fetching data for CNTX (Data #1111)...
# Fetching data for CNTY (Data #1112)...
# Fetching data for CNVS (Data #1113)...
# Fetching data for CNXA (Data #1114)...
# Fetching data for CNXC (Data #1115)...
# Fetching data for CNXN (Data #1116)...Fetching data for COCO (Data #1117)...
#
# Fetching data for COCP (Data #1118)...
# Fetching data for CODA (Data #1119)...
# Fetching data for CODX (Data #1120)...
# Fetching data for COEP (Data #1121)...
# Fetching data for COEPW (Data #1122)...
# Fetching data for COFS (Data #1123)...
# Fetching data for COGT (Data #1124)...
# Fetching data for COHU (Data #1125)...
# Fetching data for COIN (Data #1126)...
# Fetching data for COKE (Data #1127)...
# Fetching data for COLB (Data #1128)...
# Fetching data for COLL (Data #1129)...
# Fetching data for COLM (Data #1130)...
# Fetching data for COMM (Data #1131)...
# Fetching data for COMS (Data #1132)...
# Fetching data for COMSP (Data #1133)...
# Fetching data for COMSW (Data #1134)...
# Fetching data for COMT (Data #1135)...
# Fetching data for CONL (Data #1136)...
# Fetching data for CONN (Data #1137)...
# Fetching data for CONX (Data #1138)...
# Fetching data for CONXU (Data #1139)...
# Fetching data for CONXW (Data #1140)...
# Fetching data for COOL (Data #1141)...
# Fetching data for COOLU (Data #1142)...
# Fetching data for COOLW (Data #1143)...
# Fetching data for COOP (Data #1144)...
# Fetching data for COPJ (Data #1145)...
# Fetching data for CORT (Data #1146)...
# Fetching data for COSM (Data #1147)...
# Fetching data for COST (Data #1148)...
# Fetching data for COWG (Data #1149)...
# Fetching data for COYA (Data #1150)...
# Fetching data for CPAA (Data #1151)...
# Fetching data for CPAAU (Data #1152)...
# Fetching data for CPAAW (Data #1153)...
# Fetching data for CPHC (Data #1154)...
# Fetching data for CPIX (Data #1155)...
# Fetching data for CPLP (Data #1156)...
# Fetching data for CPOP (Data #1157)...
# Fetching data for CPRT (Data #1158)...
# Fetching data for CPRX (Data #1159)...
# Fetching data for CPSH (Data #1160)...
# Fetching data for CPSI (Data #1161)...
# Fetching data for CPSS (Data #1162)...
# Fetching data for CPTN (Data #1163)...
# Fetching data for CPTNW (Data #1164)...
# Fetching data for CPZ (Data #1165)...
# Fetching data for CRAI (Data #1166)...
# Fetching data for CRBP (Data #1167)...
# Fetching data for CRBU (Data #1168)...
# Fetching data for CRCT (Data #1169)...
# Fetching data for CRDF (Data #1170)...
# Fetching data for CRDL (Data #1171)...
# Fetching data for CRDO (Data #1172)...
# Fetching data for CREG (Data #1173)...
# Fetching data for CRESW (Data #1174)...
# Fetching data for CRESY (Data #1175)...
# Fetching data for CREX (Data #1176)...
# Fetching data for CREXW (Data #1177)...
# Fetching data for CRGE (Data #1178)...Fetching data for CRGO (Data #1179)...
#
# Fetching data for CRGOW (Data #1180)...
# Fetching data for CRIS (Data #1181)...
# Fetching data for CRKN (Data #1182)...
# Fetching data for CRMD (Data #1183)...
# Fetching data for CRMT (Data #1184)...
# Fetching data for CRNC (Data #1185)...
# Fetching data for CRNT (Data #1186)...
# Fetching data for CRNX (Data #1187)...
# Fetching data for CRON (Data #1188)...
# Fetching data for CROX (Data #1189)...
# Fetching data for CRSP (Data #1190)...
# Fetching data for CRSR (Data #1191)...
# Fetching data for CRTO (Data #1192)...
# Fetching data for CRUS (Data #1193)...
# Fetching data for CRVL (Data #1194)...
# Fetching data for CRVS (Data #1195)...
# Fetching data for CRWD (Data #1196)...
# Fetching data for CRWS (Data #1197)...
# Fetching data for CSA (Data #1198)...
# Fetching data for CSB (Data #1199)...
# Fetching data for CSBR (Data #1200)...
# Fetching data for CSCO (Data #1201)...Fetching data for CSF (Data #1202)...
#
# Fetching data for CSGP (Data #1203)...
# Fetching data for CSGS (Data #1204)...
# Fetching data for CSIQ (Data #1205)...
# Fetching data for CSLM (Data #1206)...
# Fetching data for CSLMR (Data #1207)...
# Fetching data for CSLMU (Data #1208)...
# Fetching data for CSLMW (Data #1209)...
# Fetching data for CSLR (Data #1210)...
# Fetching data for CSLRW (Data #1211)...
# Fetching data for CSML (Data #1212)...
# Fetching data for CSPI (Data #1213)...
# Fetching data for CSQ (Data #1214)...
# Fetching data for CSSE (Data #1215)...
# Fetching data for CSSEL (Data #1216)...
# Fetching data for CSSEN (Data #1217)...
# Fetching data for CSSEP (Data #1218)...
# Fetching data for CSTE (Data #1219)...
# Fetching data for CSTL (Data #1220)...
# Fetching data for CSTR (Data #1221)...
# Fetching data for CSWC (Data #1222)...
# Fetching data for CSWCZ (Data #1223)...
# Fetching data for CSWI (Data #1224)...
# Fetching data for CSX (Data #1225)...
# Fetching data for CTAS (Data #1226)...
# Fetching data for CTBI (Data #1227)...
# Fetching data for CTCX (Data #1228)...
# Fetching data for CTCXW (Data #1229)...
# Fetching data for CTEC (Data #1230)...
# Fetching data for CTG (Data #1231)...
# Fetching data for CTHR (Data #1232)...
# Fetching data for CTIB (Data #1233)...
# Fetching data for CTKB (Data #1234)...
# Fetching data for CTLP (Data #1235)...
# Fetching data for CTMX (Data #1236)...
# Fetching data for CTRM (Data #1237)...
# Fetching data for CTRN (Data #1238)...
# Fetching data for CTSH (Data #1239)...
# Fetching data for CTSO (Data #1240)...
# Fetching data for CTXR (Data #1241)...
# Fetching data for CUBA (Data #1242)...
# Fetching data for CUE (Data #1243)...
# Fetching data for CUEN (Data #1244)...
# Fetching data for CUENW (Data #1245)...
# Fetching data for CULL (Data #1246)...
# Fetching data for CURI (Data #1247)...
# Fetching data for CURIW (Data #1248)...
# Fetching data for CUTR (Data #1249)...
# Fetching data for CVAC (Data #1250)...
# Fetching data for CVBF (Data #1251)...
# Fetching data for CVCO (Data #1252)...
# Fetching data for CVCY (Data #1253)...
# Fetching data for CVGI (Data #1254)...
# ...
# Fetching data for VIIAU (Data #4853)...
# Fetching data for VIIAW (Data #4854)...
# Fetching data for VINC (Data #4855)...
# Fetching data for VINO (Data #4856)...
# Fetching data for VINP (Data #4857)...
# Fetching data for VIOT (Data #4858)...
# Fetching data for VIR (Data #4859)...
# Fetching data for VIRC (Data #4860)...
# Fetching data for VIRI (Data #4861)...
# Fetching data for VIRT (Data #4862)...
# Fetching data for VIRX (Data #4863)...
# Fetching data for VISL (Data #4864)...Fetching data for VITL (Data #4865)...
#
# Fetching data for VIVK (Data #4866)...
# Fetching data for VJET (Data #4867)...
# Fetching data for VKTX (Data #4868)...
# Fetching data for VLCN (Data #4869)...
# Fetching data for VLGEA (Data #4870)...
# Fetching data for VLY (Data #4871)...
# Fetching data for VLYPO (Data #4872)...
# Fetching data for VLYPP (Data #4873)...
# Fetching data for VMAR (Data #4874)...
# Fetching data for VMBS (Data #4875)...
# Fetching data for VMCA (Data #4876)...
# Fetching data for VMCAU (Data #4877)...
# Fetching data for VMCAW (Data #4878)...
# Fetching data for VMD (Data #4879)...
# Fetching data for VMEO (Data #4880)...
# Fetching data for VNDA (Data #4881)...
# Fetching data for VNET (Data #4882)...
# Fetching data for VNOM (Data #4883)...
# Fetching data for VNQI (Data #4884)...
# Fetching data for VOD (Data #4885)...
# Fetching data for VONE (Data #4886)...
# Fetching data for VONG (Data #4887)...
# Fetching data for VONV (Data #4888)...Fetching data for VOR (Data #4889)...
#
# Fetching data for VOXR (Data #4890)...
# Fetching data for VOXX (Data #4891)...
# Fetching data for VPN (Data #4892)...
# Fetching data for VQS (Data #4893)...
# Fetching data for VR (Data #4894)...
# Fetching data for VRA (Data #4895)...
# Fetching data for VRAR (Data #4896)...
# Fetching data for VRAX (Data #4897)...
# Fetching data for VRCA (Data #4898)...
# Fetching data for VRDN (Data #4899)...
# Fetching data for VREX (Data #4900)...
# Fetching data for VRIG (Data #4901)...
# Fetching data for VRM (Data #4902)...
# Fetching data for VRME (Data #4903)...
# Fetching data for VRMEW (Data #4904)...
# Fetching data for VRNA (Data #4905)...
# Fetching data for VRNS (Data #4906)...
# Fetching data for VRNT (Data #4907)...
# Fetching data for VRPX (Data #4908)...
# Fetching data for VRRM (Data #4909)...
# Fetching data for VRSK (Data #4910)...
# Fetching data for VRSN (Data #4911)...
# Fetching data for VRTS (Data #4912)...
# Fetching data for VRTX (Data #4913)...
# Fetching data for VS (Data #4914)...
# Fetching data for VSAC (Data #4915)...
# Fetching data for VSACU (Data #4916)...
# Fetching data for VSACW (Data #4917)...
# Fetching data for VSAT (Data #4918)...
# Fetching data for VSDA (Data #4919)...
# Fetching data for VSEC (Data #4920)...
# Fetching data for VSMV (Data #4921)...
# Fetching data for VSSYW (Data #4922)...
# Fetching data for VSTA (Data #4923)...
# Fetching data for VSTM (Data #4924)...
# Fetching data for VTC (Data #4925)...
# Fetching data for VTGN (Data #4926)...
# Fetching data for VTHR (Data #4927)...
# Fetching data for VTIP (Data #4928)...
# Fetching data for VTNR (Data #4929)...
# Fetching data for VTRS (Data #4930)...
# Fetching data for VTRU (Data #4931)...
# Fetching data for VTSI (Data #4932)...
# Fetching data for VTVT (Data #4933)...
# Fetching data for VTWG (Data #4934)...
# Fetching data for VTWO (Data #4935)...
# Fetching data for VTWV (Data #4936)...
# Fetching data for VTYX (Data #4937)...
# Fetching data for VUZI (Data #4938)...
# Fetching data for VVOS (Data #4939)...
# Fetching data for VVPR (Data #4940)...Fetching data for VWE (Data #4941)...
#
# Fetching data for VWEWW (Data #4942)...
# Fetching data for VWOB (Data #4943)...
# Fetching data for VXRT (Data #4944)...
# Fetching data for VXUS (Data #4945)...Fetching data for VYGR (Data #4946)...
#
# Fetching data for VYMI (Data #4947)...
# Fetching data for VYNE (Data #4948)...
# Fetching data for WABC (Data #4949)...
# Fetching data for WAFD (Data #4950)...
# Fetching data for WAFDP (Data #4951)...
# Fetching data for WAFU (Data #4952)...
# Fetching data for WALD (Data #4953)...Fetching data for WALDW (Data #4954)...
#
# Fetching data for WASH (Data #4955)...
# Fetching data for WATT (Data #4956)...
# Fetching data for WAVD (Data #4957)...
# Fetching data for WAVE (Data #4958)...
# Fetching data for WAVS (Data #4959)...
# Fetching data for WAVSU (Data #4960)...
# Fetching data for WAVSW (Data #4961)...
# Fetching data for WB (Data #4962)...
# Fetching data for WBA (Data #4963)...
# Fetching data for WBD (Data #4964)...
# Fetching data for WBND (Data #4965)...
# Fetching data for WCBR (Data #4966)...
# Fetching data for WCLD (Data #4967)...
# Fetching data for WDAY (Data #4968)...
# Fetching data for WDC (Data #4969)...
# Fetching data for WDFC (Data #4970)...
# Fetching data for WEN (Data #4971)...
# Fetching data for WERN (Data #4972)...
# Fetching data for WEST (Data #4973)...
# Fetching data for WESTW (Data #4974)...
# Fetching data for WETG (Data #4975)...
# Fetching data for WEYS (Data #4976)...
# Fetching data for WFCF (Data #4977)...
# Fetching data for XBIT (Data #5055)...
# Fetching data for XCUR (Data #5056)...
# Fetching data for XDNA (Data #5057)...
# Fetching data for XEL (Data #5058)...
# Fetching data for XELA (Data #5059)...
# Fetching data for XELAP (Data #5060)...
# Fetching data for XELB (Data #5061)...
# Fetching data for XENE (Data #5062)...
# Fetching data for XERS (Data #5063)...
# Fetching data for XFIN (Data #5064)...
# Fetching data for XFINU (Data #5065)...
# Fetching data for XFINW (Data #5066)...
# Fetching data for XFOR (Data #5067)...
# Fetching data for XGN (Data #5068)...
# Fetching data for XLO (Data #5069)...
# Fetching data for XMTR (Data #5070)...
# Fetching data for XNCR (Data #5071)...
# Fetching data for XNET (Data #5072)...
# Fetching data for XOMA (Data #5073)...
# Fetching data for XOMAO (Data #5074)...
# Fetching data for XOMAP (Data #5075)...
# Fetching data for XOS (Data #5076)...
# Fetching data for XOSWW (Data #5077)...
# Fetching data for XP (Data #5078)...
# Fetching data for XPAX (Data #5079)...
# Fetching data for XPAXU (Data #5080)...
# Fetching data for XPAXW (Data #5081)...
# Fetching data for XPDB (Data #5082)...
# Fetching data for XPDBU (Data #5083)...
# Fetching data for XPDBW (Data #5084)...
# Fetching data for XPEL (Data #5085)...
# Fetching data for XPON (Data #5086)...
# Fetching data for XRAY (Data #5087)...
# Fetching data for XRTX (Data #5088)...
# Fetching data for XRX (Data #5089)...
# Fetching data for XT (Data #5090)...
# Fetching data for XTLB (Data #5091)...Fetching data for XWEL (Data #5092)...
#
# Fetching data for XXII (Data #5093)...
# Fetching data for YELL (Data #5094)...
# Fetching data for YGF (Data #5095)...
# Fetching data for YGMZ (Data #5096)...
# Fetching data for YI (Data #5097)...
# Fetching data for YJ (Data #5098)...
# Fetching data for YLDE (Data #5099)...
# Fetching data for YMAB (Data #5100)...
# Fetching data for YNDX (Data #5101)...
# Fetching data for YORW (Data #5102)...
# Fetching data for YOSH (Data #5103)...
# Fetching data for YOTA (Data #5104)...
# Fetching data for YOTAR (Data #5105)...
# Fetching data for YOTAU (Data #5106)...
# Fetching data for YOTAW (Data #5107)...
# Fetching data for YQ (Data #5108)...Fetching data for YS (Data #5109)...
#
# Fetching data for YSBPW (Data #5110)...
# Fetching data for YTEN (Data #5111)...
# Fetching data for YTRA (Data #5112)...
# Fetching data for YVR (Data #5113)...
# Fetching data for YY (Data #5114)...
# Fetching data for Z (Data #5115)...
# Fetching data for ZAPP (Data #5116)...
# Fetching data for ZAPPW (Data #5117)...
# Fetching data for ZAZZT (Data #5118)...
# Fetching data for ZBRA (Data #5119)...
# Fetching data for ZBZZT (Data #5120)...
# Fetching data for ZCMD (Data #5121)...
# Fetching data for ZCZZT (Data #5122)...
# Fetching data for ZD (Data #5123)...
# Fetching data for ZENV (Data #5124)...
# Fetching data for ZEUS (Data #5125)...
# Fetching data for ZFOX (Data #5126)...
# Fetching data for ZFOXW (Data #5127)...
# Fetching data for ZG (Data #5128)...
# Fetching data for ZI (Data #5129)...
# Fetching data for ZIMV (Data #5130)...
# Fetching data for ZING (Data #5131)...
# Fetching data for ZINGU (Data #5132)...
# Fetching data for ZINGW (Data #5133)...
# Fetching data for ZION (Data #5134)...
# Fetching data for ZIONL (Data #5135)...
# Fetching data for ZIONO (Data #5136)...
# Fetching data for ZIONP (Data #5137)...
# Fetching data for ZIVO (Data #5138)...
# Fetching data for ZIVOW (Data #5139)...
# Fetching data for ZJYL (Data #5140)...
# Fetching data for ZJZZT (Data #5141)...
# Fetching data for ZKIN (Data #5142)...
# Fetching data for ZLAB (Data #5143)...
# Fetching data for ZM (Data #5144)...
# Fetching data for ZNTL (Data #5145)...
# Fetching data for ZS (Data #5146)...
# Fetching data for ZTEK (Data #5147)...
# Fetching data for ZUMZ (Data #5148)...
# Fetching data for ZURA (Data #5149)...
# Fetching data for ZURAW (Data #5150)...
# Fetching data for ZVRA (Data #5151)...
# Fetching data for ZVSA (Data #5152)...
# Fetching data for ZVZZC (Data #5153)...
# Fetching data for ZVZZT (Data #5154)...
# Fetching data for ZWZZT (Data #5155)...
# Fetching data for ZXYZ.A (Data #5156)...
# Fetching data for ZXZZT (Data #5157)...
# Fetching data for ZYME (Data #5158)...
# Fetching data for ZYNE (Data #5159)...
# Fetching data for ZYXI (Data #5160)...
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /var/folders/w4/tykm_45x4bxdj2p9kjtbk3b00000gn/T/ipykernel_12812/2421827800.py in <module>
#      14
#      15 # 결과를 딕셔너리에 저장
# ---> 16 for index, (ticker, info) in enumerate(results):
#      17     nasdaq_info_dict[ticker] = info
#
# ~/opt/anaconda3/lib/python3.9/concurrent/futures/_base.py in result_iterator()
#     607                     # Careful not to keep a reference to the popped future
#     608                     if timeout is None:
# --> 609                         yield fs.pop().result()
#     610                     else:
#     611                         yield fs.pop().result(end_time - time.monotonic())
#
# ~/opt/anaconda3/lib/python3.9/concurrent/futures/_base.py in result(self, timeout)
#     437                     raise CancelledError()
#     438                 elif self._state == FINISHED:
# --> 439                     return self.__get_result()
#     440
#     441                 self._condition.wait(timeout)
#
# ~/opt/anaconda3/lib/python3.9/concurrent/futures/_base.py in __get_result(self)
#     389         if self._exception:
#     390             try:
# --> 391                 raise self._exception
#     392             finally:
#     393                 # Break a reference cycle with the exception in self._exception
#
# ~/opt/anaconda3/lib/python3.9/concurrent/futures/thread.py in run(self)
#      56
#      57         try:
# ---> 58             result = self.fn(*self.args, **self.kwargs)
#      59         except BaseException as exc:
#      60             self.future.set_exception(exc)
#
# /var/folders/w4/tykm_45x4bxdj2p9kjtbk3b00000gn/T/ipykernel_12812/2421827800.py in get_stock_info(ticker, index)
#       5 def get_stock_info(ticker, index):
#       6     print(f"Fetching data for {ticker} (Data #{index + 1})...")
# ----> 7     return ticker, yf.Ticker(ticker).info
#       8
#       9 nasdaq_info_dict = {}
#
# ~/opt/anaconda3/lib/python3.9/site-packages/yfinance/ticker.py in info(self)
#     136     @property
#     137     def info(self) -> dict:
# --> 138         return self.get_info()
#     139
#     140     @property
#
# ~/opt/anaconda3/lib/python3.9/site-packages/yfinance/base.py in get_info(self, proxy)
#    1494     def get_info(self, proxy=None) -> dict:
#    1495         self._quote.proxy = proxy
# -> 1496         data = self._quote.info
#    1497         return data
#    1498
#
# ~/opt/anaconda3/lib/python3.9/site-packages/yfinance/scrapers/quote.py in info(self)
#     561     def info(self) -> dict:
#     562         if self._info is None:
# --> 563             self._fetch(self.proxy)
#     564             self._fetch_complementary(self.proxy)
#     565
#
# ~/opt/anaconda3/lib/python3.9/site-packages/yfinance/scrapers/quote.py in _fetch(self, proxy)
#     592         params_dict["modules"] = modules
#     593         params_dict["ssl"] = "true"
# --> 594         result = self._data.get_raw_json(
#     595             _BASIC_URL_ + f"/{self._data.ticker}", params=params_dict, proxy=proxy
#     596         )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/yfinance/data.py in get_raw_json(self, url, user_agent_headers, params, proxy, timeout)
#      73     def get_raw_json(self, url, user_agent_headers=None, params=None, proxy=None, timeout=30):
#      74         response = self.get(url, user_agent_headers=user_agent_headers, params=params, proxy=proxy, timeout=timeout)
# ---> 75         response.raise_for_status()
#      76         return response.json()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/models.py in raise_for_status(self)
#    1019
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#    1023     def close(self):
#
# HTTPError: 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/ZXYZ.A?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true

# %%
import pandas as pd
nasdaq_info_df = pd.DataFrame(nasdaq_info_dict).T.reset_index()

# %%
nasdaq_info_df
# Out:
#       index                    address1  \
# 0      AACG              Building No. 2
# 1      AACI          1760 Market Street
# 2     AACIU          1760 Market Street
# 3     AACIW                         NaN
# 4      AADI      17383 Sunset Boulevard
# ...     ...                         ...
# 5150   ZVRA  1180 Celebration Boulevard
# 5151   ZVSA    2200 N. Commerce Parkway
# 5152  ZVZZC                         NaN
# 5153  ZVZZT                         NaN
# 5154  ZWZZT                         NaN
#
#                                                address2               city  \
# 0     East Gate, Floor 1 Jian Wai Soho No.39 Dong Sa...            Beijing
# 1                                             Suite 602       Philadelphia
# 2                                             Suite 602       Philadelphia
# 3                                                   NaN                NaN
# 4                                            Suite A250  Pacific Palisades
# ...                                                 ...                ...
# 5150                                          Suite 103        Celebration
# 5151                                          Suite 208             Weston
# 5152                                                NaN                NaN
# 5153                                                NaN                NaN
# 5154                                                NaN                NaN
#
#          zip        country            phone              fax  \
# 0     100022          China  86 10 6518 1133  86 10 5869 8106
# 1      19103  United States     212 543 6886              NaN
# 2      19103  United States     212 543 6886              NaN
# 3        NaN            NaN              NaN              NaN
# 4      90272  United States     424 473 8055              NaN
# ...      ...            ...              ...              ...
# 5150   34747  United States     321 939 3416              NaN
# 5151   33326  United States   (754) 231-1688              NaN
# 5152     NaN            NaN              NaN              NaN
# 5153     NaN            NaN              NaN              NaN
# 5154     NaN            NaN              NaN              NaN
#
#                       website                       industry  ...  \
# 0     https://www.atai.net.cn  Education & Training Services  ...
# 1       https://armadaacq.com                Shell Companies  ...
# 2       https://armadaacq.com                Shell Companies  ...
# 3                         NaN                            NaN  ...
# 4         https://aadibio.com                  Biotechnology  ...
# ...                       ...                            ...  ...
# 5150        https://zevra.com                  Biotechnology  ...
# 5151  https://www.zyversa.com                  Biotechnology  ...
# 5152                      NaN                            NaN  ...
# 5153                      NaN                            NaN  ...
# 5154                      NaN                            NaN  ...
#
#      threeYearAverageReturn fiveYearAverageReturn lastSplitFactor  \
# 0                       NaN                   NaN             NaN
# 1                       NaN                   NaN             NaN
# 2                       NaN                   NaN             NaN
# 3                       NaN                   NaN             NaN
# 4                       NaN                   NaN             NaN
# ...                     ...                   ...             ...
# 5150                    NaN                   NaN             NaN
# 5151                    NaN                   NaN             NaN
# 5152                    NaN                   NaN             NaN
# 5153                    NaN                   NaN             NaN
# 5154                    NaN                   NaN             NaN
#
#      lastSplitDate dividendRate dividendYield fiveYearAvgDividendYield  \
# 0              NaN          NaN           NaN                      NaN
# 1              NaN          NaN           NaN                      NaN
# 2              NaN          NaN           NaN                      NaN
# 3              NaN          NaN           NaN                      NaN
# 4              NaN          NaN           NaN                      NaN
# ...            ...          ...           ...                      ...
# 5150           NaN          NaN           NaN                      NaN
# 5151           NaN          NaN           NaN                      NaN
# 5152           NaN          NaN           NaN                      NaN
# 5153           NaN          NaN           NaN                      NaN
# 5154           NaN          NaN           NaN                      NaN
#
#      earningsQuarterlyGrowth earningsGrowth openInterest
# 0                        NaN            NaN          NaN
# 1                        NaN            NaN          NaN
# 2                        NaN            NaN          NaN
# 3                        NaN            NaN          NaN
# 4                        NaN            NaN          NaN
# ...                      ...            ...          ...
# 5150                     NaN            NaN          NaN
# 5151                     NaN            NaN          NaN
# 5152                     NaN            NaN          NaN
# 5153                     NaN            NaN          NaN
# 5154                     NaN            NaN          NaN
#
# [5155 rows x 136 columns]

# %%
nasdaq_info_df.drop(nasdaq_info_df.index[5152:], inplace=True)

# %%
nasdaq_info_df
# Out:
#       index                    address1  \
# 0      AACG              Building No. 2
# 1      AACI          1760 Market Street
# 2     AACIU          1760 Market Street
# 3     AACIW                         NaN
# 4      AADI      17383 Sunset Boulevard
# ...     ...                         ...
# 5147   ZUMZ        4001 204th Street SW
# 5148   ZURA       4225 Executive Square
# 5149  ZURAW       4225 Executive Square
# 5150   ZVRA  1180 Celebration Boulevard
# 5151   ZVSA    2200 N. Commerce Parkway
#
#                                                address2               city  \
# 0     East Gate, Floor 1 Jian Wai Soho No.39 Dong Sa...            Beijing
# 1                                             Suite 602       Philadelphia
# 2                                             Suite 602       Philadelphia
# 3                                                   NaN                NaN
# 4                                            Suite A250  Pacific Palisades
# ...                                                 ...                ...
# 5147                                                NaN           Lynnwood
# 5148                                          Suite 600          San Diego
# 5149                                          Suite 600          San Diego
# 5150                                          Suite 103        Celebration
# 5151                                          Suite 208             Weston
#
#          zip        country            phone              fax  \
# 0     100022          China  86 10 6518 1133  86 10 5869 8106
# 1      19103  United States     212 543 6886              NaN
# 2      19103  United States     212 543 6886              NaN
# 3        NaN            NaN              NaN              NaN
# 4      90272  United States     424 473 8055              NaN
# ...      ...            ...              ...              ...
# 5147   98036  United States     425 551 1500              NaN
# 5148   92037  United States     858-247-0520              NaN
# 5149   92037  United States     858-247-0520              NaN
# 5150   34747  United States     321 939 3416              NaN
# 5151   33326  United States   (754) 231-1688              NaN
#
#                       website                       industry  ...  \
# 0     https://www.atai.net.cn  Education & Training Services  ...
# 1       https://armadaacq.com                Shell Companies  ...
# 2       https://armadaacq.com                Shell Companies  ...
# 3                         NaN                            NaN  ...
# 4         https://aadibio.com                  Biotechnology  ...
# ...                       ...                            ...  ...
# 5147   https://www.zumiez.com                 Apparel Retail  ...
# 5148      https://zurabio.com                  Biotechnology  ...
# 5149      https://zurabio.com                  Biotechnology  ...
# 5150        https://zevra.com                  Biotechnology  ...
# 5151  https://www.zyversa.com                  Biotechnology  ...
#
#      threeYearAverageReturn fiveYearAverageReturn lastSplitFactor  \
# 0                       NaN                   NaN             NaN
# 1                       NaN                   NaN             NaN
# 2                       NaN                   NaN             NaN
# 3                       NaN                   NaN             NaN
# 4                       NaN                   NaN             NaN
# ...                     ...                   ...             ...
# 5147                    NaN                   NaN             2:1
# 5148                    NaN                   NaN             NaN
# 5149                    NaN                   NaN             NaN
# 5150                    NaN                   NaN             NaN
# 5151                    NaN                   NaN             NaN
#
#      lastSplitDate dividendRate dividendYield fiveYearAvgDividendYield  \
# 0              NaN          NaN           NaN                      NaN
# 1              NaN          NaN           NaN                      NaN
# 2              NaN          NaN           NaN                      NaN
# 3              NaN          NaN           NaN                      NaN
# 4              NaN          NaN           NaN                      NaN
# ...            ...          ...           ...                      ...
# 5147    1145491200          NaN           NaN                      NaN
# 5148           NaN          NaN           NaN                      NaN
# 5149           NaN          NaN           NaN                      NaN
# 5150           NaN          NaN           NaN                      NaN
# 5151           NaN          NaN           NaN                      NaN
#
#      earningsQuarterlyGrowth earningsGrowth openInterest
# 0                        NaN            NaN          NaN
# 1                        NaN            NaN          NaN
# 2                        NaN            NaN          NaN
# 3                        NaN            NaN          NaN
# 4                        NaN            NaN          NaN
# ...                      ...            ...          ...
# 5147                     NaN            NaN          NaN
# 5148                     NaN            NaN          NaN
# 5149                     NaN            NaN          NaN
# 5150                     NaN            NaN          NaN
# 5151                     NaN            NaN          NaN
#
# [5152 rows x 136 columns]

# %%
selected_keys = [
    "country",
    "industry",
    "sector",
    "fullTimeEmployees",
    "auditRisk",
    "boardRisk",
    "compensationRisk",
    "shareHolderRightsRisk",
    "overallRisk",
    "dividendRate",
    "dividendYield",
    "payoutRatio",
    "fiveYearAvgDividendYield",
    "beta",
    "trailingPE",
    "forwardPE",
    "volume",
    "regularMarketVolume",
    "averageVolume",
    "averageVolume10days",
    "averageDailyVolume10Day",
    "marketCap",
    "fiftyTwoWeekLow",
    "fiftyTwoWeekHigh",
    "priceToSalesTrailing12Months",
    "twoHundredDayAverage",
    "trailingAnnualDividendRate",
    "trailingAnnualDividendYield",
    "currency",
    "enterpriseValue",
    "profitMargins",
    "heldPercentInsiders",
    "heldPercentInstitutions",
    "bookValue",
    "priceToBook",
    "earningsQuarterlyGrowth",
    "netIncomeToCommon",
    "trailingEps",
    "forwardEps",
    "pegRatio",
    "enterpriseToRevenue",
    "enterpriseToEbitda",
    "targetHighPrice",
    "targetLowPrice",
    "targetMeanPrice",
    "targetMedianPrice",
    "recommendationMean",
    "recommendationKey",
    "numberOfAnalystOpinions",
    "totalCash",
    "totalDebt",
    "quickRatio",
    "currentRatio",
    "totalRevenue",
    "debtToEquity",
    "revenuePerShare",
    "returnOnAssets",
    "returnOnEquity",
    "grossProfits",
    "freeCashflow",
    "operatingCashflow",
    "earningsGrowth",
    "revenueGrowth",
    "grossMargins",
    "ebitdaMargins",
    "operatingMargins",
    "financialCurrency",
    "trailingPegRatio"
]

# %%
nasdaq_info_df = nasdaq_info_df[selected_keys]

# %%
nasdaq_info_df.to_excel("nasdaq_info_df.xlsx")
